# %%
import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import pandas as pd

# %%
ss = pd.read_excel('/Users/aishweryaakapoor/Downloads/Superman graphs/All graphs - ss - top.xlsx',header=1)
crustalss = ss
ss["X-Dir RSN57"] = ss["X-Dir RSN57"].apply(lambda x : np.abs(x))
ss["X-Dir RSN313"] = ss["X-Dir RSN313"].apply(lambda x : np.abs(x))
ss["X-Dir RSN139"] = ss["X-Dir RSN139"].apply(lambda x : np.abs(x))
ss["X-Dir RSN739"] = ss["X-Dir RSN739"].apply(lambda x : np.abs(x))
ss["X-Dir Mean"] = ss["X-Dir Mean"].apply(lambda x : np.abs(x))

ss["Y-Dir RSN57"] = ss["Y-Dir RSN57"].apply(lambda x : np.abs(x))
ss["Y-Dir RSN313"] = ss["Y-Dir RSN313"].apply(lambda x : np.abs(x))
ss["Y-Dir RSN139"] = ss["Y-Dir RSN139"].apply(lambda x : np.abs(x))
ss["Y-Dir RSN739"] = ss["Y-Dir RSN739"].apply(lambda x : np.abs(x))
ss["Y-Dir Mean"] = ss["Y-Dir Mean"].apply(lambda x : np.abs(x))


ss['index'] = ss.index.values.tolist()
ss = ss.sort_values('index',ascending=False)


fig = go.Figure()

fig.add_trace(go.Scatter(x=ss["X-Dir RSN57"], y=ss["Story"],
                    mode='lines',
                    name='X RSN57',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["X-Dir RSN313"], y=ss["Story"],
                    mode='lines',
                    name='X RSN313',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["X-Dir RSN139"], y=ss["Story"],
                    mode='lines',
                    name='X RSN139',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=ss["X-Dir RSN739"], y=ss["Story"],
                    mode='lines',
                    name='X RSN739',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["X-Dir Mean"], y=ss["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = ss['Elevation'].values.tolist(),
        ticktext = ss['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.update_layout(title='Story Shear X-Direction',xaxis_title='Shear (kN)',yaxis_title='Story')

fig.show()

fig = go.Figure()

fig.add_trace(go.Scatter(x=ss["Y-Dir RSN57"], y=ss["Story"],
                    mode='lines',
                    name='Y RSN57',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["Y-Dir RSN313"], y=ss["Story"],
                    mode='lines',
                    name='Y RSN313',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["Y-Dir RSN139"], y=ss["Story"],
                    mode='lines',
                    name='Y RSN139',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=ss["Y-Dir RSN739"], y=ss["Story"],
                    mode='lines',
                    name='Y RSN739',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["Y-Dir Mean"], y=ss["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = ss['Elevation'].values.tolist(),
        ticktext = ss['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.update_layout(title='Story Shear Y-Direction',xaxis_title='Shear (kN)',yaxis_title='Story')

fig.show()

# %%
##for d

d = pd.read_excel('/Users/aishweryaakapoor/Downloads/Superman graphs/All graphs - drif.xlsx',header=0)
crustald = d
d['index'] = d.index.values.tolist()
d = d.sort_values('index',ascending=False)

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["X-Dir RSN57"], y=d["Story"],
                    mode='lines',
                    name='X RSN57',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["X-Dir RSN313"], y=d["Story"],
                    mode='lines',
                    name='X RSN313',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["X-Dir RSN139"], y=d["Story"],
                    mode='lines',
                    name='X RSN139',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["X-Dir RSN739"], y=d["Story"],
                    mode='lines',
                    name='X RSN739',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["X-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Story Drift X-Direction',xaxis_title='Drift (m)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Y-Dir RSN57"], y=d["Story"],
                    mode='lines',
                    name='Y RSN57',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Y-Dir RSN313"], y=d["Story"],
                    mode='lines',
                    name='Y RSN313',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Y-Dir RSN139"], y=d["Story"],
                    mode='lines',
                    name='Y RSN139',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Y-Dir RSN739"], y=d["Story"],
                    mode='lines',
                    name='Y RSN739',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["Y-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Story Drift Y-Direction',xaxis_title='Drift (m)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
## for om

om = pd.read_excel('/Users/aishweryaakapoor/Downloads/Superman graphs/All graphs - om.xlsx',header=0)
crustalom = om
om['index'] = om.index.values.tolist()
om = om.sort_values('index',ascending=False)

om["X-Dir RSN57"] = om["X-Dir RSN57"].apply(lambda x : np.abs(x))
om["X-Dir RSN313"] = om["X-Dir RSN313"].apply(lambda x : np.abs(x))
om["X-Dir RSN139"] = om["X-Dir RSN139"].apply(lambda x : np.abs(x))
om["X-Dir RSN739"] = om["X-Dir RSN739"].apply(lambda x : np.abs(x))
om["X-Dir Mean"] = om["X-Dir Mean"].apply(lambda x : np.abs(x))

om["Y-Dir RSN57"] = om["Y-Dir RSN57"].apply(lambda x : np.abs(x))
om["Y-Dir RSN313"] = om["Y-Dir RSN313"].apply(lambda x : np.abs(x))
om["Y-Dir RSN139"] = om["Y-Dir RSN139"].apply(lambda x : np.abs(x))
om["Y-Dir RSN739"] = om["Y-Dir RSN739"].apply(lambda x : np.abs(x))
om["Y-Dir Mean"] = om["Y-Dir Mean"].apply(lambda x : np.abs(x))

fig = go.Figure()

fig.add_trace(go.Scatter(x=om["X-Dir RSN57"], y=om["Story"],
                    mode='lines',
                    name='X RSN57',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["X-Dir RSN313"], y=om["Story"],
                    mode='lines',
                    name='X RSN313',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["X-Dir RSN139"], y=om["Story"],
                    mode='lines',
                    name='X RSN139',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=om["X-Dir RSN739"], y=om["Story"],
                    mode='lines',
                    name='X RSN739',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=om["X-Dir Mean"], y=om["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Overturning Moment X-Direction',xaxis_title='Overturning Moment (kN-m)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = om['Elevation'].values.tolist(),
        ticktext = om['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()

fig.add_trace(go.Scatter(x=om["Y-Dir RSN57"], y=om["Story"],
                    mode='lines',
                    name='Y RSN57',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir RSN313"], y=om["Story"],
                    mode='lines',
                    name='Y RSN313',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir RSN139"], y=om["Story"],
                    mode='lines',
                    name='Y RSN139',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=om["Y-Dir RSN739"], y=om["Story"],
                    mode='lines',
                    name='Y RSN739',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir Mean"], y=om["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Overturning Moment Y-Direction',xaxis_title='Overturning Moment (kN-m)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = om['Elevation'].values.tolist(),
        ticktext = om['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#INSLAB
#Story Shear X

ss = pd.read_excel('/Users/aishweryaakapoor/Downloads/inslab/ss.xlsx','Newnorm',header=0)
inslabss = ss

ss = ss[['Story','Elevation','X-Dir Nisqually 1416','Y-Dir Nisqually 1416',
         'X-Dir Geiyo','Y-Dir Geiyo','X-Dir Olympia','Y-Dir Olympia',
         'X-Dir Puget Sound','Y-Dir Puget Sound','X-Dir Nisqually 1421','Y-Dir Nisqually 1421',
         'X-Dir Mean','Y-Dir Mean']]

ss['index'] = ss.index.values.tolist()
ss = ss.sort_values('index',ascending=False)

ss["X-Dir Nisqually 1416"] = ss["X-Dir Nisqually 1416"].apply(lambda x : np.abs(x))
ss["X-Dir Geiyo"] = ss["X-Dir Geiyo"].apply(lambda x : np.abs(x))
ss["X-Dir Olympia"] = ss["X-Dir Olympia"].apply(lambda x : np.abs(x))
ss["X-Dir Puget Sound"] = ss["X-Dir Puget Sound"].apply(lambda x : np.abs(x))
ss["X-Dir Nisqually 1421"] = ss["X-Dir Nisqually 1421"].apply(lambda x : np.abs(x))
ss["X-Dir Mean"] = ss["X-Dir Mean"].apply(lambda x : np.abs(x))

ss["Y-Dir Nisqually 1416"] = ss["Y-Dir Nisqually 1416"].apply(lambda x : np.abs(x))
ss["Y-Dir Geiyo"] = ss["Y-Dir Geiyo"].apply(lambda x : np.abs(x))
ss["Y-Dir Olympia"] = ss["Y-Dir Olympia"].apply(lambda x : np.abs(x))
ss["Y-Dir Puget Sound"] = ss["Y-Dir Puget Sound"].apply(lambda x : np.abs(x))
ss["Y-Dir Nisqually 1421"] = ss["Y-Dir Nisqually 1421"].apply(lambda x : np.abs(x))
ss["Y-Dir Mean"] = ss["Y-Dir Mean"].apply(lambda x : np.abs(x))


fig = go.Figure()

fig.add_trace(go.Scatter(x=ss["X-Dir Nisqually 1416"], y=ss["Story"],
                    mode='lines',
                    name='X Nisqually 1416',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["X-Dir Geiyo"], y=ss["Story"],
                    mode='lines',
                    name='X Geiyo',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["X-Dir Olympia"], y=ss["Story"],
                    mode='lines',
                    name='X Olympia',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=ss["X-Dir Puget Sound"], y=ss["Story"],
                    mode='lines',
                    name='X Puget Sound',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["X-Dir Mean"], y=ss["Story"],
                    mode='lines',
                    line=dict(width=4),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=1000)
fig.update_layout(title='Story Shear X-Direction',xaxis_title='Shear (kN)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = ss['Elevation'].values.tolist(),
        ticktext = ss['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

#INSLAB
#Story Shear Y

fig = go.Figure()

fig.add_trace(go.Scatter(x=ss["Y-Dir Nisqually 1416"], y=ss["Story"],
                    mode='lines',
                    name='Y Nisqually 1416',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["Y-Dir Geiyo"], y=ss["Story"],
                    mode='lines',
                    name='Y Geiyo',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["Y-Dir Olympia"], y=ss["Story"],
                    mode='lines',
                    name='Y Olympia',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=ss["Y-Dir Puget Sound"], y=ss["Story"],
                    mode='lines',
                    name='Y Puget Sound',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=ss["Y-Dir Mean"], y=ss["Story"],
                    mode='lines',
                    line=dict(width=4),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Story Shear Y-Direction',xaxis_title='Shear (kN)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = ss['Elevation'].values.tolist(),
        ticktext = ss['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()

# %%
#INSLAB
#OM x

om = pd.read_excel('/Users/aishweryaakapoor/Downloads/inslab/om.xlsx','Normalised',header=0)
inslabom=om
om = om[['Story','Elevation','X-Dir Nisqually 1416','Y-Dir Nisqually 1416',
         'X-Dir Geiyo','Y-Dir Geiyo','X-Dir Olympia','Y-Dir Olympia',
         'X-Dir Puget Sound','Y-Dir Puget Sound',
         'X-Dir Mean','Y-Dir Mean']]

om['index'] = om.index.values.tolist()
om = om.sort_values('index',ascending=False)

om["X-Dir Nisqually 1416"] = om["X-Dir Nisqually 1416"].apply(lambda x : np.abs(x))
om["X-Dir Geiyo"] = om["X-Dir Geiyo"].apply(lambda x : np.abs(x))
om["X-Dir Olympia"] = om["X-Dir Olympia"].apply(lambda x : np.abs(x))
om["X-Dir Puget Sound"] = om["X-Dir Puget Sound"].apply(lambda x : np.abs(x))
om["X-Dir Mean"] = om["X-Dir Mean"].apply(lambda x : np.abs(x))

om["Y-Dir Nisqually 1416"] = om["Y-Dir Nisqually 1416"].apply(lambda x : np.abs(x))
om["Y-Dir Geiyo"] = om["Y-Dir Geiyo"].apply(lambda x : np.abs(x))
om["Y-Dir Olympia"] = om["Y-Dir Olympia"].apply(lambda x : np.abs(x))
om["Y-Dir Puget Sound"] = om["Y-Dir Puget Sound"].apply(lambda x : np.abs(x))
om["Y-Dir Mean"] = om["Y-Dir Mean"].apply(lambda x : np.abs(x))

fig = go.Figure()

fig.add_trace(go.Scatter(x=om["Y-Dir Nisqually 1416"], y=om["Story"],
                    mode='lines',
                    name='Y Nisqually 1416',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir Geiyo"], y=om["Story"],
                    mode='lines',
                    name='Y Geiyo',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir Olympia"], y=om["Story"],
                    mode='lines',
                    name='Y Olympia',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=om["Y-Dir Puget Sound"], y=om["Story"],
                    mode='lines',
                    name='Y Puget Sound',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir Mean"], y=om["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Overturning Moment X-Direction')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = om['Elevation'].values.tolist(),
        ticktext = om['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()

#INSLAB
#OM Y

fig = go.Figure()

fig.add_trace(go.Scatter(x=om["Y-Dir Nisqually 1416"], y=om["Story"],
                    mode='lines',
                    name='Y Nisqually 1416',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir Geiyo"], y=om["Story"],
                    mode='lines',
                    name='Y Geiyo',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=om["Y-Dir Olympia"], y=om["Story"],
                    mode='lines',
                    name='Y Olympia',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=om["Y-Dir Puget Sound"], y=om["Story"],
                    mode='lines',
                    name='Y Puget Sound',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=om["Y-Dir Mean"], y=om["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Overturning Moment Y-Direction')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = om['Elevation'].values.tolist(),
        ticktext = om['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()

# %%
#INSLAB
#Drift X

drift = pd.read_excel('/Users/aishweryaakapoor/Downloads/inslab/drift.xlsx','Normalised',header=0)
inslabd = drift

drift = drift[['Story','Elevation','X-Dir Nisqually 1416','Y-Dir Nisqually 1416',
         'X-Dir Geiyo','Y-Dir Geiyo','X-Dir Olympia','Y-Dir Olympia',
         'X-Dir Puget Sound','Y-Dir Puget Sound',
         'X-Dir Mean','Y-Dir Mean']]

drift['index'] = drift.index.values.tolist()
drift = drift.sort_values('index',ascending=False)

drift["X-Dir Nisqually 1416"] = drift["X-Dir Nisqually 1416"].apply(lambda x : np.abs(x))
drift["X-Dir Geiyo"] = drift["X-Dir Geiyo"].apply(lambda x : np.abs(x))
drift["X-Dir Olympia"] = drift["X-Dir Olympia"].apply(lambda x : np.abs(x))
drift["X-Dir Puget Sound"] = drift["X-Dir Puget Sound"].apply(lambda x : np.abs(x))
drift["X-Dir Mean"] = drift["X-Dir Mean"].apply(lambda x : np.abs(x))

drift["Y-Dir Nisqually 1416"] = drift["Y-Dir Nisqually 1416"].apply(lambda x : np.abs(x))
drift["Y-Dir Geiyo"] = drift["Y-Dir Geiyo"].apply(lambda x : np.abs(x))
drift["Y-Dir Olympia"] = drift["Y-Dir Olympia"].apply(lambda x : np.abs(x))
drift["Y-Dir Puget Sound"] = drift["Y-Dir Puget Sound"].apply(lambda x : np.abs(x))
drift["Y-Dir Mean"] = drift["Y-Dir Mean"].apply(lambda x : np.abs(x))


fig = go.Figure()

fig.add_trace(go.Scatter(x=drift["Y-Dir Nisqually 1416"], y=drift["Story"],
                    mode='lines',
                    name='Y Nisqually 1416',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=drift["Y-Dir Geiyo"], y=drift["Story"],
                    mode='lines',
                    name='Y Geiyo',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=drift["Y-Dir Olympia"], y=drift["Story"],
                    mode='lines',
                    name='Y Olympia',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=drift["Y-Dir Puget Sound"], y=drift["Story"],
                    mode='lines',
                    name='Y Puget Sound',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=drift["Y-Dir Mean"], y=drift["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Drift X-Direction',yaxis_title='Story',xaxis_title='Displacement(m)')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = drift['Elevation'].values.tolist(),
        ticktext = drift['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()

#INSLAB
#Drift Y

fig = go.Figure()

fig.add_trace(go.Scatter(x=drift["Y-Dir Nisqually 1416"], y=drift["Story"],
                    mode='lines',
                    name='Y Nisqually 1416',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=drift["Y-Dir Geiyo"], y=drift["Story"],
                    mode='lines',
                    name='Y Geiyo',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=drift["Y-Dir Olympia"], y=drift["Story"],
                    mode='lines',
                    name='Y Olympia',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=drift["Y-Dir Puget Sound"], y=drift["Story"],
                    mode='lines',
                    name='Y Puget Sound',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=drift["Y-Dir Mean"], y=drift["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Drift Y-Direction',yaxis_title='Story',xaxis_title='Displacement(m)')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = drift['Elevation'].values.tolist(),
        ticktext = drift['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)

fig.show()

# %%
#question 1 a
basex = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1.a.xlsx','Base shear RS X')
basey = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1.a.xlsx','Base shear RS Y')
omx = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1.a.xlsx','Overturning moment RSX')
omy = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1.a.xlsx','Overturning moment RSY')
driftx = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1.a.xlsx','Storey drift RSX')
drifty = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1.a.xlsx','Storey Drift RSY')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y=basex['Elevation'],x=basex['Site C'],name='Site C',mode='lines+markers'))
fig.add_trace(go.Scatter(y=basex['Elevation'],x=basex['Site D'],name='Site D',mode='lines+markers'))
fig.add_trace(go.Scatter(y=basex['Elevation'],x=basex['line'],name='',showlegend=False,mode='lines+markers',marker=dict(color='green')))
fig.update_layout(title='Base Shear X-Dir',xaxis_title='Base Shear in kN',yaxis_title='Storey',height=800,template='simple_white')
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = basex['Elevation'],
        ticktext = basex['Storey'].values.tolist()
    )
)
fig.add_shape(
        dict(
            type="line",
            x0=0,
            y0=0,
            x1=7000,
            y1=0,
            line=dict(
                color="green",
                width=3
            )
))
fig.update_layout(height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(y=basey['Elevation'],x=basey['Site C'],name='Site C',mode='lines+markers'))
fig.add_trace(go.Scatter(y=basey['Elevation'],x=basey['Site D'],name='Site D',mode='lines+markers'))
fig.add_trace(go.Scatter(y=basey['Elevation'],x=basey['line'],name='',showlegend=False,mode='lines+markers',marker=dict(color='green')))
fig.update_layout(title='Base Shear Y-Dir',xaxis_title='Base Shear in kN',yaxis_title='Storey',height=800,template='simple_white')
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = basey['Elevation'],
        ticktext = basey['Storey'].values.tolist()
    )
)
fig.add_shape(
        dict(
            type="line",
            x0=0,
            y0=0,
            x1=7000,
            y1=0,
            line=dict(
                color="green",
                width=3
            )
))
fig.update_layout(height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y=omx['Elevation'],x=omx['Site C'],name='Site C',mode='lines+markers'))
fig.add_trace(go.Scatter(y=omx['Elevation'],x=omx['Site D'],name='Site D',mode='lines+markers'))
fig.add_trace(go.Scatter(y=omx['Elevation'],x=omx['line'],name='',showlegend=False,mode='lines+markers',marker=dict(color='green')))
fig.update_layout(title='Overturning Moment X-Dir',xaxis_title='Overturning Moment in kN-m',yaxis_title='Storey',height=800,template='simple_white')
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = omx['Elevation'],
        ticktext = omx['Storey'].values.tolist()
    )
)
fig.add_shape(
        dict(
            type="line",
            x0=0,
            y0=0,
            x1=360000,
            y1=0,
            line=dict(
                color="green",
                width=3
            )
))
fig.update_layout(height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(y=omy['Elevation'],x=omy['Site C'],name='Site C',mode='lines+markers'))
fig.add_trace(go.Scatter(y=omy['Elevation'],x=omy['Site D'],name='Site D',mode='lines+markers'))
fig.add_trace(go.Scatter(y=omy['Elevation'],x=omy['line'],name='',showlegend=False,mode='lines+markers',marker=dict(color='green')))
fig.update_layout(title='Overturning Moment Y-Dir',xaxis_title='Overturning Moment in kN-m',yaxis_title='Storey',height=800,template='simple_white')
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = omy['Elevation'],
        ticktext = omy['Storey'].values.tolist()
    )
)
fig.add_shape(
        dict(
            type="line",
            x0=0,
            y0=0,
            x1=360000,
            y1=0,
            line=dict(
                color="green",
                width=3
            )
))
fig.update_layout(height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y=driftx['Elevation'],x=driftx['Site C new'],name='Site C',mode='lines+markers'))
fig.add_trace(go.Scatter(y=driftx['Elevation'],x=driftx['Site D new'],name='Site D',mode='lines+markers'))
fig.add_trace(go.Scatter(y=driftx['Elevation'],x=driftx['line'],name='',showlegend=False,mode='lines+markers',marker=dict(color='green')))
fig.update_layout(title='Storey Drift X-Dir',xaxis_title='Storey Drift in mm',yaxis_title='Storey',height=800,template='simple_white')
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = driftx['Elevation'],
        ticktext = driftx['Storey'].values.tolist()
    )
)
fig.add_shape(
        dict(
            type="line",
            x0=0,
            y0=0,
            x1=3,
            y1=0,
            line=dict(
                color="green",
                width=3
            )
))
fig.update_layout(height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(y=drifty['Elevation'],x=drifty['Site C new'],name='Site C',mode='lines+markers'))
fig.add_trace(go.Scatter(y=drifty['Elevation'],x=drifty['Site D new'],name='Site D',mode='lines+markers'))
fig.add_trace(go.Scatter(y=drifty['Elevation'],x=drifty['line'],name='',showlegend=False,mode='lines+markers',marker=dict(color='green')))
fig.update_layout(title='Storey Drift Y-Dir',xaxis_title='Storey Drift in mm',yaxis_title='Storey',height=800,template='simple_white')
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = drifty['Elevation'],
        ticktext = drifty['Storey'].values.tolist()
    )
)
fig.add_shape(
        dict(
            type="line",
            x0=0,
            y0=0,
            x1=3,
            y1=0,
            line=dict(
                color="green",
                width=3
            )
))
fig.update_layout(height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#question2

myfile = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','Q2')
myfile2 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','NS Base shear')
myfile3 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','NS Overturning moment')
myfile4 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','EW Base shear')
myfile5 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','EW Overturning moment')
myfile6 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','EW localization')
myfile7 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Graphs Q1b,c,d.xlsx','NS localization')
myfile8 = pd.read_excel('/Users/aishweryaakapoor/Downloads/Charts 3.xlsx','Sheet2')

# %%
#Base Shear in coupling wall direction NS
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile['Displacement'],y=myfile['No wall fibers'],name='No wall fibers',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile['Displacement2'],y=myfile['Including wall fibers'],name='Including wall fibers',mode='lines+markers'))
fig.update_layout(title='Base Shear in coupling wall direction',yaxis_title='Base Shear in kN',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# Base shear in Cantilevered wall direction
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile2['Displacement'],y=myfile2['No Pdelta'],name='No Pdelta',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile2['Displacement2'],y=myfile2['With Pdelta'],name='With Pdelta',mode='lines+markers'))
fig.update_layout(title='Base shear in Cantilevered wall direction',yaxis_title='Base Shear in kN',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#Base Shear in coupling wall direction EW
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile4['Displacement'],y=myfile4['No Pdelta'],name='No Pdelta',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile4['Displacement2'],y=myfile4['With Pdelta'],name='With Pdelta',mode='lines+markers'))
fig.update_layout(title='Base Shear in coupling wall direction',yaxis_title='Base Shear in kN',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
# Overturning moment in Cantilevered wall direction

fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile3['Displacement'],y=myfile3['No Pdelta'],name='No Pdelta',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile3['Displacement2'],y=myfile3['With Pdelta'],name='With Pdelta',mode='lines+markers'))
fig.update_layout(title='Overturning moment in Cantilevered wall direction',yaxis_title='Moment in kNm',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
# Overturning moment in Coupling wall direction pdelta
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile5['Displacement'],y=myfile5['No Pdelta'],name='No Pdelta',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile5['Displacement2'],y=myfile5['With Pdelta'],name='With Pdelta',mode='lines+markers'))
fig.update_layout(title='Overturning Moment in coupling wall direction',yaxis_title='Moment in kNm',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
# Overturning moment in Coupling wall direction fibres
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile8['Displacement'],y=myfile8['No Wall fiber'],name='No wall fiber',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile8['Displacement2'],y=myfile8['Including wall fiber'],name='Including wall fiber',mode='lines+markers'))
fig.update_layout(title='Overturning Moment in coupling wall direction',xaxis_title='Displacement in mm',yaxis_title='Moment in kNm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#Localization effect in Coupling wall direction
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile6['Displacement'],y=myfile6['One'],name='One',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile6['Displacement2'],y=myfile6['Three'],name='Three',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile6['Displacement3'],y=myfile6['Nine'],name='Nine',mode='lines+markers'))
fig.update_layout(title='Localization effect in Coupling wall direction',yaxis_title='Base Shear in kN',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#Localization effect in Cantilevered wall direction
fig = go.Figure()
fig.add_trace(go.Scatter(x=myfile7['Displacement'],y=myfile7['One'],name='One',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile7['Displacement2'],y=myfile7['Three'],name='Three',mode='lines+markers'))
fig.add_trace(go.Scatter(x=myfile7['Displacement3'],y=myfile7['Nine'],name='Nine',mode='lines+markers'))
fig.update_layout(title='Localization effect in Cantilevered wall direction',yaxis_title='Base Shear in kN',xaxis_title='Displacement in mm',height=800,template='simple_white')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#SUBDUCTION

#drift
##for d

d = pd.read_excel('/Users/aishweryaakapoor/Downloads/subduction drift.xlsx',header=0)
subd = d

d['index'] = d.index.values.tolist()
d = d.sort_values('index',ascending=False)

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Maule-Stgola-X"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stgola-X',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Maule-Stl-X"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stl-X',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Tohuku-MYG-X"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-MYG-X',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Tohuku-TKY-X"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-TKY-X',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["X-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
#                             px.colors.sequential.Rainbow[8],
                            'black'],
                 height=800)
fig.update_layout(title='Story Drift X-Direction',xaxis_title='Drift (m)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Maule-Stgola-Y"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stgola-Y',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Maule-Stl-Y"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stl-Y',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Tohuku-MYG-Y"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-MYG-Y',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Tohuku-TKY-Y"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-TKY-Y',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["Y-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
#                             px.colors.sequential.Rainbow[8],
                            'black'],
                 height=800)
fig.update_layout(title='Story Drift Y-Direction',xaxis_title='Drift (m)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#SUBDUCTION

#shear

d = pd.read_excel('/Users/aishweryaakapoor/Downloads/subduction ss.xlsx',header=0)
subss = d
d['index'] = d.index.values.tolist()
d = d.sort_values('index',ascending=False)

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Maule-Stgola-X"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stgola-X',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Maule-Stl-X"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stl-X',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Tohuku-MYG-X"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-MYG-X',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Tohuku-TKY-X"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-TKY-X',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["X-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
#                             px.colors.sequential.Rainbow[8],
                            'black'],
                 height=800)
fig.update_layout(title='Story Shear X-Direction',xaxis_title='Shear (kN)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Maule-Stgola-Y"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stgola-Y',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Maule-Stl-Y"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stl-Y',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Tohuku-MYG-Y"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-MYG-Y',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Tohuku-TKY-Y"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-TKY-Y',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["Y-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
#                             px.colors.sequential.Rainbow[8],
                            'black'],
                 height=800)
fig.update_layout(title='Story Shear Y-Direction',xaxis_title='Shear (kN)',yaxis_title='Story')

fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
#SUBDUCTION

#om


d = pd.read_excel('/Users/aishweryaakapoor/Downloads/subduction om.xlsx',header=0)
subom = d
d['index'] = d.index.values.tolist()
d = d.sort_values('index',ascending=False)

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Maule-Stgola-X"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stgola-X',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Maule-Stl-X"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stl-X',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Tohuku-MYG-X"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-MYG-X',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Tohuku-TKY-X"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-TKY-X',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["X-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='X-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
#                             px.colors.sequential.Rainbow[8],
                            'black'],
                 height=800)
fig.update_layout(title='Overturning Moment X-Direction',xaxis_title='Moment (kNm)',yaxis_title='Story')
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

fig = go.Figure()

fig.add_trace(go.Scatter(x=d["Maule-Stgola-Y"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stgola-Y',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Maule-Stl-Y"], y=d["Story"],
                    mode='lines',
                    name='Maule-Stl-Y',
                        line=dict(dash='dash')))
fig.add_trace(go.Scatter(x=d["Tohuku-MYG-Y"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-MYG-Y',line=dict(dash='dash')
                        ))
fig.add_trace(go.Scatter(x=d["Tohuku-TKY-Y"], y=d["Story"],
                    mode='lines',
                    name='Tohuku-TKY-Y',
                        line=dict(dash='dash')))

fig.add_trace(go.Scatter(x=d["Y-Dir Mean"], y=d["Story"],
                    mode='lines',
                    line=dict(width=3),
                    name='Y-Mean'))

fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
#                             px.colors.sequential.Rainbow[8],
                            'black'],
                 height=800)
fig.update_layout(title='Overturning Moment Y-Direction',xaxis_title='Moment (kNm)',yaxis_title='Story')

fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
# All of them together
print(crustalss.columns)
print(crustald.columns)
print(crustalom.columns)
print(inslabss.columns)
print(inslabd.columns)
print(inslabom.columns)
print(subss.columns)
print(subd.columns)
print(subom.columns)

# %%
allss = pd.concat([crustalss,inslabss,subss],axis=1)
alld = pd.concat([crustald,inslabd,subd],axis=1)
allom = pd.concat([crustalom,inslabom,subom],axis=1)

# %%
allss.to_excel('allss.xlsx')
alld.to_excel('alld.xlsx')
allom.to_excel('allom.xlsx')

# %%
plot1 = pd.read_excel('/Users/aishweryaakapoor/Downloads/allss.xlsx','Sheet2',header=0)
plot1['index']=plot1.index
plot1 = plot1.sort_values('index',ascending=False)
plot1['X-Dir Mean inslab'] = plot1['X-Dir Mean inslab'].apply(lambda x: np.abs(x))
plot1['Y-Dir Mean inslab'] = plot1['Y-Dir Mean inslab'].apply(lambda x: np.abs(x))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean crustal'],y=plot1['Story'],mode='lines',name='X-Dir Mean crustal'))
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean inslab'],y=plot1['Story'],mode='lines',name='X-Dir Mean inslab'))
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean sub'],y=plot1['Story'],mode='lines',name='X-Dir Mean sub'))
fig.add_trace(go.Scatter(x=plot1['Global X mean'],y=plot1['Story'],mode='lines',name='Global X mean'))
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.update_layout(title='Comparison X SS')
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean crustal'],y=plot1['Story'],mode='lines',name='Y-Dir Mean crustal'))
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean inslab'],y=plot1['Story'],mode='lines',name='Y-Dir Mean inslab'))
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean sub'],y=plot1['Story'],mode='lines',name='Y-Dir Mean sub'))
fig.add_trace(go.Scatter(x=plot1['Global Y mean'],y=plot1['Story'],mode='lines',name='Global Y mean'))
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Comparison Y SS')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
plot1 = pd.read_excel('/Users/aishweryaakapoor/Downloads/alld.xlsx','Sheet2',header=0)

plot1 = plot1.sort_values('index',ascending=False)
plot1['X-Dir Mean inslab'] = plot1['X-Dir Mean inslab'].apply(lambda x: np.abs(x))
plot1['Y-Dir Mean inslab'] = plot1['Y-Dir Mean inslab'].apply(lambda x: np.abs(x))

fig = go.Figure()
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean crustal'],y=plot1['Story'],mode='lines',name='X-Dir Mean crustal'))
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean inslab'],y=plot1['Story'],mode='lines',name='X-Dir Mean inslab'))
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean sub'],y=plot1['Story'],mode='lines',name='X-Dir Mean sub'))
fig.add_trace(go.Scatter(x=plot1['Global X mean'],y=plot1['Story'],mode='lines',name='Global X mean'))
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.update_layout(title='Comparison X Drift')
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean crustal'],y=plot1['Story'],mode='lines',name='Y-Dir Mean crustal'))
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean inslab'],y=plot1['Story'],mode='lines',name='Y-Dir Mean inslab'))
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean sub'],y=plot1['Story'],mode='lines',name='Y-Dir Mean sub'))
fig.add_trace(go.Scatter(x=plot1['Global Y mean'],y=plot1['Story'],mode='lines',name='Global Y mean'))
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Comparison Y Drift')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()

# %%
plot1 = pd.read_excel('/Users/aishweryaakapoor/Downloads/allom.xlsx','Sheet2',header=0)

plot1 = plot1.sort_values('index',ascending=False)
plot1['X-Dir Mean inslab'] = plot1['X-Dir Mean inslab'].apply(lambda x: np.abs(x))
plot1['Y-Dir Mean inslab'] = plot1['Y-Dir Mean inslab'].apply(lambda x: np.abs(x))
plot1['X-Dir Mean crustal'] = plot1['X-Dir Mean crustal'].apply(lambda x: np.abs(x))
plot1['Y-Dir Mean crustal'] = plot1['Y-Dir Mean crustal'].apply(lambda x: np.abs(x))


fig = go.Figure()
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean crustal'],y=plot1['Story'],mode='lines',name='X-Dir Mean crustal'))
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean inslab'],y=plot1['Story'],mode='lines',name='X-Dir Mean inslab'))
fig.add_trace(go.Scatter(x=plot1['X-Dir Mean sub'],y=plot1['Story'],mode='lines',name='X-Dir Mean sub'))
fig.add_trace(go.Scatter(x=plot1['Global X mean'],y=plot1['Story'],mode='lines',name='Global X mean'))
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.update_layout(title='Comparison X OM')
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean crustal'],y=plot1['Story'],mode='lines',name='Y-Dir Mean crustal'))
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean inslab'],y=plot1['Story'],mode='lines',name='Y-Dir Mean inslab'))
fig.add_trace(go.Scatter(x=plot1['Y-Dir Mean sub'],y=plot1['Story'],mode='lines',name='Y-Dir Mean sub'))
fig.add_trace(go.Scatter(x=plot1['Global Y mean'],y=plot1['Story'],mode='lines',name='Global Y mean'))
fig.update_layout(
    yaxis = dict(
        tickmode = 'linear',
        tickvals = d['Elevation'].values.tolist(),
        ticktext = d['Story'].values.tolist()
    )
)
fig.update_layout(template="simple_white",
                  colorway=[px.colors.sequential.Rainbow[1],
                            px.colors.sequential.Rainbow[3],
                            px.colors.sequential.Rainbow[5],
                            px.colors.sequential.Rainbow[7],
                            'black'],
                 height=800)
fig.update_layout(title='Comparison Y OM')
fig.update_xaxes(showgrid=True)
fig.update_yaxes(showgrid=True)
fig.show()
